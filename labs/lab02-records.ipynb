# %% [markdown]
# COMP 215 - LAB 2 Records (NEO)
# ----------------
# #### Name:
# #### Date:
#
# This lab exercise is mostly a review of strings, tuples, lists, dictionaries, and functions.
#
# **Building on new concepts from lab 1**:
#   * `datetime.date` objects represent a calendar date
#   * *list comprehension* provides a compact way to represent map and filter algorithms
#
# **New Python Concepts**:
#   * *f-string* simplifies string formatting operations
#
# As usual, the first code cell simply imports all the modules we'll be using...

# %%
import datetime, json, requests
from pprint import pprint    # Pretty Print - built-in python function to nicely format data structures

# %% [markdown]
# We'll answer some questions about [Near Earth Objects](https://cneos.jpl.nasa.gov/)
# > using NASA's API:  [https://api.nasa.gov/](https://api.nasa.gov/#NeoWS)
#
# You should register for your own API key, (but may use the DEMO_KEY to get started).
#
# First we need a short tutorial on python dates and [f-strings](https://realpython.com/python-f-strings/)...

# %%
today = datetime.date.today()   # get a date object representing today's date
print(today, type(today))
formatted_date = f'Today is: {today}'   # A format string - notice how the variable `today` is formatted into the stringg
print(formatted_date)
# Out:
# 2024-01-17 <class 'datetime.date'>
# Today is: 2024-01-17

# %% [markdown]
# ### Make a query
#
# Let's get some data from the NEO database...
# Here's a query that gets the observation "feed" for today.
# (Note: I hard-coded the date below to lock down the data for the lab - ideally used `today()` so the notebook is always up-to-date.)

# %%
API_KEY = 'cMYIfUR8gTcV62HNrLgfqP4Rk5lBJPtX3C7Sr0dH'  # substitute your API key here

today = str(datetime.date.today())  #  Future enhancement:  str(datetime.date.today())   # Today's date as a string!
# Use an f-string here to "format" the date and API key varaibles.
url = f'https://api.nasa.gov/neo/rest/v1/feed?start_date={today}&end_date={today}&api_key={API_KEY}'

response = requests.request("GET", url, headers={}, data={})

data = json.loads(response.text)  # recall json.loads for lab 1

# TIP: print(data) to see the whole data structure returned, here we grab just the list of NEO's:
n_results = data['element_count']
neos = data['near_earth_objects'][today]
print(f'{n_results} Near Earth Objects found for {today}')
pprint(neos[:5])
# Out:
# 10 Near Earth Objects found for 2024-01-17
# [{'absolute_magnitude_h': 20.64,
#   'close_approach_data': [{'close_approach_date': '2024-01-17',
#                            'close_approach_date_full': '2024-Jan-17 01:09',
#                            'epoch_date_close_approach': 1705453740000,
#                            'miss_distance': {'astronomical': '0.2589935197',
#                                              'kilometers': '38744878.890923039',
#                                              'lunar': '100.7484791633',
#                                              'miles': '24074951.3724903782'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '58462.0681932806',
#                                                  'kilometers_per_second': '16.239463387',
#                                                  'miles_per_hour': '36326.0556504304'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 1452.1953105872,
#                                   'estimated_diameter_min': 649.4414862159},
#                          'kilometers': {'estimated_diameter_max': 0.4426291165,
#                                         'estimated_diameter_min': 0.1979497587},
#                          'meters': {'estimated_diameter_max': 442.6291165029,
#                                     'estimated_diameter_min': 197.9497586642},
#                          'miles': {'estimated_diameter_max': 0.2750368968,
#                                    'estimated_diameter_min': 0.1230002395}},
#   'id': '3009717',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3009717?api_key=cMYIfUR8gTcV62HNrLgfqP4Rk5lBJPtX3C7Sr0dH'},
#   'name': '(1997 AC11)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3009717',
#   'neo_reference_id': '3009717'},
#  {'absolute_magnitude_h': 24.9,
#   'close_approach_data': [{'close_approach_date': '2024-01-17',
#                            'close_approach_date_full': '2024-Jan-17 01:20',
#                            'epoch_date_close_approach': 1705454400000,
#                            'miss_distance': {'astronomical': '0.3176955428',
#                                              'kilometers': '47526576.511373836',
#                                              'lunar': '123.5835661492',
#                                              'miles': '29531645.2435814968'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '39526.7707377122',
#                                                  'kilometers_per_second': '10.9796585383',
#                                                  'miles_per_hour': '24560.398184219'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 204.1855621004,
#                                   'estimated_diameter_min': 91.3145593761},
#                          'kilometers': {'estimated_diameter_max': 0.0622357573,
#                                         'estimated_diameter_min': 0.0278326768},
#                          'meters': {'estimated_diameter_max': 62.2357573367,
#                                     'estimated_diameter_min': 27.8326768072},
#                          'miles': {'estimated_diameter_max': 0.0386714948,
#                                    'estimated_diameter_min': 0.0172944182}},
#   'id': '3623683',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3623683?api_key=cMYIfUR8gTcV62HNrLgfqP4Rk5lBJPtX3C7Sr0dH'},
#   'name': '(2013 AG53)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3623683',
#   'neo_reference_id': '3623683'},
#  {'absolute_magnitude_h': 25.9,
#   'close_approach_data': [{'close_approach_date': '2024-01-17',
#                            'close_approach_date_full': '2024-Jan-17 17:29',
#                            'epoch_date_close_approach': 1705512540000,
#                            'miss_distance': {'astronomical': '0.3831119445',
#                                              'kilometers': '57312730.868758215',
#                                              'lunar': '149.0305464105',
#                                              'miles': '35612479.589224767'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '17286.4447443101',
#                                                  'kilometers_per_second': '4.8017902068',
#                                                  'miles_per_hour': '10741.1245134854'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 128.8323800441,
#                                   'estimated_diameter_min': 57.6155918963},
#                          'kilometers': {'estimated_diameter_max': 0.0392681082,
#                                         'estimated_diameter_min': 0.0175612318},
#                          'meters': {'estimated_diameter_max': 39.2681081809,
#                                     'estimated_diameter_min': 17.561231848},
#                          'miles': {'estimated_diameter_max': 0.0244000636,
#                                    'estimated_diameter_min': 0.0109120402}},
#   'id': '3752802',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3752802?api_key=cMYIfUR8gTcV62HNrLgfqP4Rk5lBJPtX3C7Sr0dH'},
#   'name': '(2016 JN6)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3752802',
#   'neo_reference_id': '3752802'},
#  {'absolute_magnitude_h': 28.2,
#   'close_approach_data': [{'close_approach_date': '2024-01-17',
#                            'close_approach_date_full': '2024-Jan-17 05:13',
#                            'epoch_date_close_approach': 1705468380000,
#                            'miss_distance': {'astronomical': '0.4413252182',
#                                              'kilometers': '66021312.620005234',
#                                              'lunar': '171.6755098798',
#                                              'miles': '41023741.3659068692'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '70500.5066906338',
#                                                  'kilometers_per_second': '19.5834740807',
#                                                  'miles_per_hour': '43806.2731711885'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 44.6709336928,
#                                   'estimated_diameter_min': 19.9774488711},
#                          'kilometers': {'estimated_diameter_max': 0.0136157002,
#                                         'estimated_diameter_min': 0.0060891262},
#                          'meters': {'estimated_diameter_max': 13.6157001539,
#                                     'estimated_diameter_min': 6.0891262211},
#                          'miles': {'estimated_diameter_max': 0.0084604012,
#                                    'estimated_diameter_min': 0.0037836064}},
#   'id': '54101667',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54101667?api_key=cMYIfUR8gTcV62HNrLgfqP4Rk5lBJPtX3C7Sr0dH'},
#   'name': '(2020 YA2)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54101667',
#   'neo_reference_id': '54101667'},
#  {'absolute_magnitude_h': 26.98,
#   'close_approach_data': [{'close_approach_date': '2024-01-17',
#                            'close_approach_date_full': '2024-Jan-17 23:18',
#                            'epoch_date_close_approach': 1705533480000,
#                            'miss_distance': {'astronomical': '0.3972900407',
#                                              'kilometers': '59433743.860933309',
#                                              'lunar': '154.5458258323',
#                                              'miles': '36930415.9490413042'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '121775.5879724826',
#                                                  'kilometers_per_second': '33.8265522146',
#                                                  'miles_per_hour': '75666.6146487906'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 78.3474796028,
#                                   'estimated_diameter_min': 35.0380580515},
#                          'kilometers': {'estimated_diameter_max': 0.023880311,
#                                         'estimated_diameter_min': 0.0106795998},
#                          'meters': {'estimated_diameter_max': 23.8803110188,
#                                     'estimated_diameter_min': 10.6795997524},
#                          'miles': {'estimated_diameter_max': 0.0148385327,
#                                    'estimated_diameter_min': 0.0066359936}},
#   'id': '54103879',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54103879?api_key=cMYIfUR8gTcV62HNrLgfqP4Rk5lBJPtX3C7Sr0dH'},
#   'name': '(2021 AA)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54103879',
#   'neo_reference_id': '54103879'}]

# %% [markdown]
# Next we extract just the potentially hazerdous asteroids, using a Comp115-style list accumulator *loop*:

# %%
hazards =  []
for item in neos:
  if item['is_potentially_hazardous_asteroid'] is True:
    hazards.append(item)
print(f'{len(hazards)} potentially hazardous asteroids identified.')
print(hazards)
# Out:
# 0 potentially hazardous asteroids identified.
# []

# %% [markdown]
# ## Exercise 1
#
# In the code cell below, **re-write the accumulator loop above** as a [list comprehension](https://realpython.com/lessons/list-comprehensions-overview/) that implements a ["filter"](https://youtu.be/hUes6y2b--0)
# Notice how this provides a concise way to "filter" items of interest from a larger data set.

# %%
# Ex. 1 your code here
hazards = []
[hazards.append(item) for item in neos if item['is_potentially_hazardous_asteroid'] is True]
print(f'{len(hazards)} potentially hazardous asteroids identified.')
print(hazards)
# Out:
# 3 potentially hazardous asteroids identified.
# [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2226554?api_key=cMYIfUR8gTcV62HNrLgfqP4Rk5lBJPtX3C7Sr0dH'}, 'id': '2226554', 'neo_reference_id': '2226554', 'name': '226554 (2003 WR21)', 'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2226554', 'absolute_magnitude_h': 19.63, 'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.3151773333, 'estimated_diameter_max': 0.7047579421}, 'meters': {'estimated_diameter_min': 315.1773332628, 'estimated_diameter_max': 704.7579421428}, 'miles': {'estimated_diameter_min': 0.1958420547, 'estimated_diameter_max': 0.4379161473}, 'feet': {'estimated_diameter_min': 1034.046402062, 'estimated_diameter_max': 2312.1980468998}}, 'is_potentially_hazardous_asteroid': True, 'close_approach_data': [{'close_approach_date': '2023-01-09', 'close_approach_date_full': '2023-Jan-09 13:59', 'epoch_date_close_approach': 1673272740000, 'relative_velocity': {'kilometers_per_second': '8.9964844189', 'kilometers_per_hour': '32387.3439078662', 'miles_per_hour': '20124.2359965294'}, 'miss_distance': {'astronomical': '0.0725378025', 'lunar': '28.2172051725', 'kilometers': '10851500.748480675', 'miles': '6742809.896856315'}, 'orbiting_body': 'Earth'}], 'is_sentry_object': False}, {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2508908?api_key=cMYIfUR8gTcV62HNrLgfqP4Rk5lBJPtX3C7Sr0dH'}, 'id': '2508908', 'neo_reference_id': '2508908', 'name': '508908 (2003 YX1)', 'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2508908', 'absolute_magnitude_h': 20.95, 'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1716148941, 'estimated_diameter_max': 0.3837425691}, 'meters': {'estimated_diameter_min': 171.6148940774, 'estimated_diameter_max': 383.7425691085}, 'miles': {'estimated_diameter_min': 0.1066365183, 'estimated_diameter_max': 0.2384465039}, 'feet': {'estimated_diameter_min': 563.0410090849, 'estimated_diameter_max': 1258.997970434}}, 'is_potentially_hazardous_asteroid': True, 'close_approach_data': [{'close_approach_date': '2023-01-09', 'close_approach_date_full': '2023-Jan-09 03:25', 'epoch_date_close_approach': 1673234700000, 'relative_velocity': {'kilometers_per_second': '6.2939907156', 'kilometers_per_hour': '22658.3665761987', 'miles_per_hour': '14079.0278317497'}, 'miss_distance': {'astronomical': '0.1211166399', 'lunar': '47.1143729211', 'kilometers': '18118791.350597013', 'miles': '11258494.8819162594'}, 'orbiting_body': 'Earth'}], 'is_sentry_object': False}, {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3014110?api_key=cMYIfUR8gTcV62HNrLgfqP4Rk5lBJPtX3C7Sr0dH'}, 'id': '3014110', 'neo_reference_id': '3014110', 'name': '(1998 SU4)', 'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3014110', 'absolute_magnitude_h': 21.42, 'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1382149359, 'estimated_diameter_max': 0.3090579921}, 'meters': {'estimated_diameter_min': 138.2149358786, 'estimated_diameter_max': 309.0579921303}, 'miles': {'estimated_diameter_min': 0.0858827529, 'estimated_diameter_max': 0.1920396736}, 'feet': {'estimated_diameter_min': 453.461090228, 'estimated_diameter_max': 1013.9698229009}}, 'is_potentially_hazardous_asteroid': True, 'close_approach_data': [{'close_approach_date': '2023-01-09', 'close_approach_date_full': '2023-Jan-09 07:10', 'epoch_date_close_approach': 1673248200000, 'relative_velocity': {'kilometers_per_second': '33.6663496706', 'kilometers_per_hour': '121198.8588141982', 'miles_per_hour': '75308.2575781889'}, 'miss_distance': {'astronomical': '0.4928732055', 'lunar': '191.7276769395', 'kilometers': '73732781.722872285', 'miles': '45815426.073056133'}, 'orbiting_body': 'Earth'}], 'is_sentry_object': False}]

# %% [markdown]
# ## Fetch Complete Data for One Asteroid
#
# Notice that the record for each `neo` is a dictionary with `id` field that uniquely identifies this record in the database.
#
# We can use this `id` to fetch complete orbital and close approach data for the NEO.
#
# For example, this query fetches the complete data set for the first hazardous asteroid...

# %%
id = hazards[0]['id']
url = f'https://api.nasa.gov/neo/rest/v1/neo/{id}?api_key={API_KEY}'
response = requests.request("GET", url, headers={}, data={})
data = json.loads(response.text)

print(id)
pprint(data)
# Out:
# 2226554
# {'absolute_magnitude_h': 19.63,
#  'close_approach_data': [{'close_approach_date': '1900-10-30',
#                           'close_approach_date_full': '1900-Oct-30 21:15',
#                           'epoch_date_close_approach': -2182819500000,
#                           'miss_distance': {'astronomical': '0.4183489295',
#                                             'kilometers': '62584108.769980165',
#                                             'lunar': '162.7377335755',
#                                             'miles': '38887961.930909677'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30027.9641223136',
#                                                 'kilometers_per_second': '8.3411011451',
#                                                 'miles_per_hour': '18658.2091514453'}},
#                          {'close_approach_date': '1901-06-26',
#                           'close_approach_date_full': '1901-Jun-26 20:27',
#                           'epoch_date_close_approach': -2162172780000,
#                           'miss_distance': {'astronomical': '0.0308795665',
#                                             'kilometers': '4619517.374923355',
#                                             'lunar': '12.0121513685',
#                                             'miles': '2870434.992938099'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '33429.0066078308',
#                                                 'kilometers_per_second': '9.2858351688',
#                                                 'miles_per_hour': '20771.4846891824'}},
#                          {'close_approach_date': '1907-01-08',
#                           'close_approach_date_full': '1907-Jan-08 04:37',
#                           'epoch_date_close_approach': -1987528980000,
#                           'miss_distance': {'astronomical': '0.1240285628',
#                                             'kilometers': '18554408.814041236',
#                                             'lunar': '48.2471109292',
#                                             'miles': '11529175.0220956168'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '24041.8395567329',
#                                                 'kilometers_per_second': '6.6782887658',
#                                                 'miles_per_hour': '14938.6641401266'}},
#                          {'close_approach_date': '1907-09-06',
#                           'close_approach_date_full': '1907-Sep-06 10:51',
#                           'epoch_date_close_approach': -1966684140000,
#                           'miss_distance': {'astronomical': '0.4147265741',
#                                             'kilometers': '62042212.117757167',
#                                             'lunar': '161.3286373249',
#                                             'miles': '38551242.9650842246'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '26520.1894310292',
#                                                 'kilometers_per_second': '7.3667192864',
#                                                 'miles_per_hour': '16478.6143717415'}},
#                          {'close_approach_date': '1909-08-06',
#                           'close_approach_date_full': '1909-Aug-06 06:41',
#                           'epoch_date_close_approach': -1906219140000,
#                           'miss_distance': {'astronomical': '0.1317215629',
#                                             'kilometers': '19705265.242911023',
#                                             'lunar': '51.2396879681',
#                                             'miles': '12244284.0469491974'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '7812.3369916648',
#                                                 'kilometers_per_second': '2.1700936088',
#                                                 'miles_per_hour': '4854.2823935153'}},
#                          {'close_approach_date': '1912-12-22',
#                           'close_approach_date_full': '1912-Dec-22 20:02',
#                           'epoch_date_close_approach': -1799553480000,
#                           'miss_distance': {'astronomical': '0.4621490953',
#                                             'kilometers': '69136520.279307011',
#                                             'lunar': '179.7759980717',
#                                             'miles': '42959441.6457823118'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '78889.8294321746',
#                                                 'kilometers_per_second': '21.9138415089',
#                                                 'miles_per_hour': '49019.0720713421'}},
#                          {'close_approach_date': '1913-10-29',
#                           'close_approach_date_full': '1913-Oct-29 19:08',
#                           'epoch_date_close_approach': -1772686320000,
#                           'miss_distance': {'astronomical': '0.4230479233',
#                                             'kilometers': '63287068.233603371',
#                                             'lunar': '164.5656421637',
#                                             'miles': '39324760.6869776798'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30216.2057175849',
#                                                 'kilometers_per_second': '8.3933904771',
#                                                 'miles_per_hour': '18775.1751582405'}},
#                          {'close_approach_date': '1914-06-28',
#                           'close_approach_date_full': '1914-Jun-28 14:48',
#                           'epoch_date_close_approach': -1751793120000,
#                           'miss_distance': {'astronomical': '0.0438440482',
#                                             'kilometers': '6558976.222897334',
#                                             'lunar': '17.0553347498',
#                                             'miles': '4075558.8387338492'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '35203.1886452326',
#                                                 'kilometers_per_second': '9.7786635126',
#                                                 'miles_per_hour': '21873.8924112558'}},
#                          {'close_approach_date': '1919-12-30',
#                           'close_approach_date_full': '1919-Dec-30 11:27',
#                           'epoch_date_close_approach': -1578054780000,
#                           'miss_distance': {'astronomical': '0.1880351048',
#                                             'kilometers': '28129651.163306776',
#                                             'lunar': '73.1456557672',
#                                             'miles': '17478954.7229784688'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '22319.4935760318',
#                                                 'kilometers_per_second': '6.1998593267',
#                                                 'miles_per_hour': '13868.4653278404'}},
#                          {'close_approach_date': '1920-02-20',
#                           'close_approach_date_full': '1920-Feb-20 02:17',
#                           'epoch_date_close_approach': -1573594980000,
#                           'miss_distance': {'astronomical': '0.2017006043',
#                                             'kilometers': '30173980.780992841',
#                                             'lunar': '78.4615350727',
#                                             'miles': '18749242.2433935658'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '18956.769066008',
#                                                 'kilometers_per_second': '5.265769185',
#                                                 'miles_per_hour': '11778.9990899315'}},
#                          {'close_approach_date': '1920-08-27',
#                           'close_approach_date_full': '1920-Aug-27 00:15',
#                           'epoch_date_close_approach': -1557272700000,
#                           'miss_distance': {'astronomical': '0.3922376007',
#                                             'kilometers': '58677909.598630509',
#                                             'lunar': '152.5804266723',
#                                             'miles': '36460762.3165746642'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '24779.5528355995',
#                                                 'kilometers_per_second': '6.883209121',
#                                                 'miles_per_hour': '15397.0504827646'}},
#                          {'close_approach_date': '1924-12-19',
#                           'close_approach_date_full': '1924-Dec-19 14:32',
#                           'epoch_date_close_approach': -1421141280000,
#                           'miss_distance': {'astronomical': '0.1361650172',
#                                             'kilometers': '20369996.541633364',
#                                             'lunar': '52.9681916908',
#                                             'miles': '12657328.9228298632'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '7522.0545712938',
#                                                 'kilometers_per_second': '2.0894596031',
#                                                 'miles_per_hour': '4673.9121862576'}},
#                          {'close_approach_date': '1925-12-28',
#                           'close_approach_date_full': '1925-Dec-28 17:32',
#                           'epoch_date_close_approach': -1388816880000,
#                           'miss_distance': {'astronomical': '0.336454074',
#                                             'kilometers': '50332812.82322238',
#                                             'lunar': '130.880634786',
#                                             'miles': '31275359.630653644'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '65215.1719844874',
#                                                 'kilometers_per_second': '18.1153255512',
#                                                 'miles_per_hour': '40522.1717255833'}},
#                          {'close_approach_date': '1926-10-17',
#                           'close_approach_date_full': '1926-Oct-17 17:33',
#                           'epoch_date_close_approach': -1363501620000,
#                           'miss_distance': {'astronomical': '0.4449028963',
#                                             'kilometers': '66556525.643310881',
#                                             'lunar': '173.0672266607',
#                                             'miles': '41356307.3173009178'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30428.2141589622',
#                                                 'kilometers_per_second': '8.4522817108',
#                                                 'miles_per_hour': '18906.9089589396'}},
#                          {'close_approach_date': '1927-07-07',
#                           'close_approach_date_full': '1927-Jul-07 13:10',
#                           'epoch_date_close_approach': -1340794200000,
#                           'miss_distance': {'astronomical': '0.1746994542',
#                                             'kilometers': '26134666.238482554',
#                                             'lunar': '67.9580876838',
#                                             'miles': '16239328.5729210852'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '48367.7259986635',
#                                                 'kilometers_per_second': '13.4354794441',
#                                                 'miles_per_hour': '30053.8239684473'}},
#                          {'close_approach_date': '1932-12-06',
#                           'close_approach_date_full': '1932-Dec-06 07:37',
#                           'epoch_date_close_approach': -1169828580000,
#                           'miss_distance': {'astronomical': '0.2949635498',
#                                             'kilometers': '44125918.777718926',
#                                             'lunar': '114.7408208722',
#                                             'miles': '27418574.5122801388'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '25802.0046205681',
#                                                 'kilometers_per_second': '7.1672235057',
#                                                 'miles_per_hour': '16032.3622599302'}},
#                          {'close_approach_date': '1933-04-15',
#                           'close_approach_date_full': '1933-Apr-15 01:33',
#                           'epoch_date_close_approach': -1158618420000,
#                           'miss_distance': {'astronomical': '0.2180158654',
#                                             'kilometers': '32614709.090046698',
#                                             'lunar': '84.8081716406',
#                                             'miles': '20265840.4890445124'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '26552.3382283613',
#                                                 'kilometers_per_second': '7.3756495079',
#                                                 'miles_per_hour': '16498.5903841726'}},
#                          {'close_approach_date': '1933-07-30',
#                           'close_approach_date_full': '1933-Jul-30 19:05',
#                           'epoch_date_close_approach': -1149396900000,
#                           'miss_distance': {'astronomical': '0.3178379237',
#                                             'kilometers': '47547876.390742519',
#                                             'lunar': '123.6389523193',
#                                             'miles': '29544880.3749000022'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '19585.7986178151',
#                                                 'kilometers_per_second': '5.4404996161',
#                                                 'miles_per_hour': '12169.8535911641'}},
#                          {'close_approach_date': '1939-01-04',
#                           'close_approach_date_full': '1939-Jan-04 13:15',
#                           'epoch_date_close_approach': -978000300000,
#                           'miss_distance': {'astronomical': '0.1772526834',
#                                             'kilometers': '26516623.888424358',
#                                             'lunar': '68.9512938426',
#                                             'miles': '16476666.0511098204'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '47802.4982379662',
#                                                 'kilometers_per_second': '13.2784717328',
#                                                 'miles_per_hour': '29702.6134190296'}},
#                          {'close_approach_date': '1939-10-02',
#                           'close_approach_date_full': '1939-Oct-02 23:40',
#                           'epoch_date_close_approach': -954548400000,
#                           'miss_distance': {'astronomical': '0.4508022495',
#                                             'kilometers': '67439056.316408565',
#                                             'lunar': '175.3620750555',
#                                             'miles': '41904686.448885597'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '29767.9641888738',
#                                                 'kilometers_per_second': '8.2688789414',
#                                                 'miles_per_hour': '18496.6553039144'}},
#                          {'close_approach_date': '1940-07-15',
#                           'close_approach_date_full': '1940-Jul-15 08:32',
#                           'epoch_date_close_approach': -929806080000,
#                           'miss_distance': {'astronomical': '0.334534837',
#                                             'kilometers': '50045699.05599719',
#                                             'lunar': '130.134051593',
#                                             'miles': '31096955.408413622'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '64571.6182760474',
#                                                 'kilometers_per_second': '17.9365606322',
#                                                 'miles_per_hour': '40122.2924782474'}},
#                          {'close_approach_date': '1945-11-18',
#                           'close_approach_date_full': '1945-Nov-18 06:11',
#                           'epoch_date_close_approach': -761161740000,
#                           'miss_distance': {'astronomical': '0.3687533852',
#                                             'kilometers': '55164720.981209524',
#                                             'lunar': '143.4450668428',
#                                             'miles': '34277768.1364944712'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '28578.725218365',
#                                                 'kilometers_per_second': '7.9385347829',
#                                                 'miles_per_hour': '17757.7084558224'}},
#                          {'close_approach_date': '1946-05-31',
#                           'close_approach_date_full': '1946-May-31 01:45',
#                           'epoch_date_close_approach': -744416100000,
#                           'miss_distance': {'astronomical': '0.144680477',
#                                             'kilometers': '21643891.18978399',
#                                             'lunar': '56.280705553',
#                                             'miles': '13448890.351999462'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '24131.1377556403',
#                                                 'kilometers_per_second': '6.703093821',
#                                                 'miles_per_hour': '14994.15056822'}},
#                          {'close_approach_date': '1952-01-09',
#                           'close_approach_date_full': '1952-Jan-09 10:55',
#                           'epoch_date_close_approach': -567349500000,
#                           'miss_distance': {'astronomical': '0.0732958703',
#                                             'kilometers': '10964906.076676261',
#                                             'lunar': '28.5120935467',
#                                             'miles': '6813276.7002079618'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '33228.5707044085',
#                                                 'kilometers_per_second': '9.230158529',
#                                                 'miles_per_hour': '20646.9416135254'}},
#                          {'close_approach_date': '1952-09-18',
#                           'close_approach_date_full': '1952-Sep-18 12:09',
#                           'epoch_date_close_approach': -545485860000,
#                           'miss_distance': {'astronomical': '0.4381149361',
#                                             'kilometers': '65541061.255746107',
#                                             'lunar': '170.4267101429',
#                                             'miles': '40725327.0058139966'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '28395.2733630013',
#                                                 'kilometers_per_second': '7.8875759342',
#                                                 'miles_per_hour': '17643.7186071382'}},
#                          {'close_approach_date': '1953-07-22',
#                           'close_approach_date_full': '1953-Jul-22 08:42',
#                           'epoch_date_close_approach': -518973480000,
#                           'miss_distance': {'astronomical': '0.4679445696',
#                                             'kilometers': '70003510.890226752',
#                                             'lunar': '182.0304375744',
#                                             'miles': '43498164.6304910976'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '78393.1807879963',
#                                                 'kilometers_per_second': '21.7758835522',
#                                                 'miles_per_hour': '48710.4739179636'}},
#                          {'close_approach_date': '1958-11-06',
#                           'close_approach_date_full': '1958-Nov-06 23:00',
#                           'epoch_date_close_approach': -351910800000,
#                           'miss_distance': {'astronomical': '0.4052166354',
#                                             'kilometers': '60619545.544406598',
#                                             'lunar': '157.6292711706',
#                                             'miles': '37667238.9482151324'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '29821.8885744541',
#                                                 'kilometers_per_second': '8.2838579373',
#                                                 'miles_per_hour': '18530.1618200545'}},
#                          {'close_approach_date': '1959-06-22',
#                           'close_approach_date_full': '1959-Jun-22 11:57',
#                           'epoch_date_close_approach': -332251380000,
#                           'miss_distance': {'astronomical': '0.0488503587',
#                                             'kilometers': '7307909.610255969',
#                                             'lunar': '19.0027895343',
#                                             'miles': '4540924.4663476122'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '28870.8198450116',
#                                                 'kilometers_per_second': '8.0196721792',
#                                                 'miles_per_hour': '17939.2046975851'}},
#                          {'close_approach_date': '1965-01-09',
#                           'close_approach_date_full': '1965-Jan-09 06:20',
#                           'epoch_date_close_approach': -157052400000,
#                           'miss_distance': {'astronomical': '0.0918946692',
#                                             'kilometers': '13747246.776674604',
#                                             'lunar': '35.7470263188',
#                                             'miles': '8542143.0425893752'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '27010.430427491',
#                                                 'kilometers_per_second': '7.502897341',
#                                                 'miles_per_hour': '16783.2310620151'}},
#                          {'close_approach_date': '1965-09-11',
#                           'close_approach_date_full': '1965-Sep-11 11:07',
#                           'epoch_date_close_approach': -135867180000,
#                           'miss_distance': {'astronomical': '0.4256120395',
#                                             'kilometers': '63670654.555555865',
#                                             'lunar': '165.5630833655',
#                                             'miles': '39563110.175026337'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '27282.9128231964',
#                                                 'kilometers_per_second': '7.5785868953',
#                                                 'miles_per_hour': '16952.5410261689'}},
#                          {'close_approach_date': '1970-12-22',
#                           'close_approach_date_full': '1970-Dec-22 03:21',
#                           'epoch_date_close_approach': 30684060000,
#                           'miss_distance': {'astronomical': '0.4970939405',
#                                             'kilometers': '74364194.688706735',
#                                             'lunar': '193.3695428545',
#                                             'miles': '46207767.896893543'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '82786.0727810646',
#                                                 'kilometers_per_second': '22.9961313281',
#                                                 'miles_per_hour': '51440.0461677676'}},
#                          {'close_approach_date': '1971-11-02',
#                           'close_approach_date_full': '1971-Nov-02 20:26',
#                           'epoch_date_close_approach': 57961560000,
#                           'miss_distance': {'astronomical': '0.4161214915',
#                                             'kilometers': '62250888.789623105',
#                                             'lunar': '161.8712601935',
#                                             'miles': '38680908.636304649'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30031.662356568',
#                                                 'kilometers_per_second': '8.3421284324',
#                                                 'miles_per_hour': '18660.5070903908'}},
#                          {'close_approach_date': '1972-06-25',
#                           'close_approach_date_full': '1972-Jun-25 18:40',
#                           'epoch_date_close_approach': 78345600000,
#                           'miss_distance': {'astronomical': '0.0287692581',
#                                             'kilometers': '4303819.733240247',
#                                             'lunar': '11.1912414009',
#                                             'miles': '2674269.5747075286'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '32284.6861527051',
#                                                 'kilometers_per_second': '8.9679683758',
#                                                 'miles_per_hour': '20060.4484597183'}},
#                          {'close_approach_date': '1978-01-06',
#                           'close_approach_date_full': '1978-Jan-06 06:31',
#                           'epoch_date_close_approach': 252916260000,
#                           'miss_distance': {'astronomical': '0.1452313182',
#                                             'kilometers': '21726295.860012234',
#                                             'lunar': '56.4949827798',
#                                             'miles': '13500094.2397234692'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '22857.4903899916',
#                                                 'kilometers_per_second': '6.3493028861',
#                                                 'miles_per_hour': '14202.7556259367'}},
#                          {'close_approach_date': '1978-09-03',
#                           'close_approach_date_full': '1978-Sep-03 16:17',
#                           'epoch_date_close_approach': 273687420000,
#                           'miss_distance': {'astronomical': '0.4089770748',
#                                             'kilometers': '61182099.268910676',
#                                             'lunar': '159.0920820972',
#                                             'miles': '38016793.6235562888'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '26109.7415764479',
#                                                 'kilometers_per_second': '7.2527059935',
#                                                 'miles_per_hour': '16223.5780367656'}},
#                          {'close_approach_date': '1983-12-26',
#                           'close_approach_date_full': '1983-Dec-26 09:46',
#                           'epoch_date_close_approach': 441279960000,
#                           'miss_distance': {'astronomical': '0.4048341469',
#                                             'kilometers': '60562326.079507103',
#                                             'lunar': '157.4804831441',
#                                             'miles': '37631684.4214119014'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '72737.7095259634',
#                                                 'kilometers_per_second': '20.2049193128',
#                                                 'miles_per_hour': '45196.3840107298'}},
#                          {'close_approach_date': '1984-10-24',
#                           'close_approach_date_full': '1984-Oct-24 02:43',
#                           'epoch_date_close_approach': 467433780000,
#                           'miss_distance': {'astronomical': '0.4350100236',
#                                             'kilometers': '65076572.959209732',
#                                             'lunar': '169.2188991804',
#                                             'miles': '40436707.3618170216'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30503.8964322348',
#                                                 'kilometers_per_second': '8.4733045645',
#                                                 'miles_per_hour': '18953.9349803517'}},
#                          {'close_approach_date': '1985-07-02',
#                           'close_approach_date_full': '1985-Jul-02 21:01',
#                           'epoch_date_close_approach': 489186060000,
#                           'miss_distance': {'astronomical': '0.1010075585',
#                                             'kilometers': '15110515.605500395',
#                                             'lunar': '39.2919402565',
#                                             'miles': '9389239.012459651'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '40996.6194947828',
#                                                 'kilometers_per_second': '11.3879498597',
#                                                 'miles_per_hour': '25473.7050410777'}},
#                          {'close_approach_date': '1990-12-18',
#                           'close_approach_date_full': '1990-Dec-18 07:58',
#                           'epoch_date_close_approach': 661507080000,
#                           'miss_distance': {'astronomical': '0.2439799312',
#                                             'kilometers': '36498878.030266544',
#                                             'lunar': '94.9081932368',
#                                             'miles': '22679351.1525205472'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '23867.4186781176',
#                                                 'kilometers_per_second': '6.6298385217',
#                                                 'miles_per_hour': '14830.2857891892'}},
#                          {'close_approach_date': '1991-03-23',
#                           'close_approach_date_full': '1991-Mar-23 17:01',
#                           'epoch_date_close_approach': 669747660000,
#                           'miss_distance': {'astronomical': '0.2222874875',
#                                             'kilometers': '33253734.657651625',
#                                             'lunar': '86.4698326375',
#                                             'miles': '20662912.564277425'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '24935.9007883861',
#                                                 'kilometers_per_second': '6.9266391079',
#                                                 'miles_per_hour': '15494.199020428'}},
#                          {'close_approach_date': '1991-08-17',
#                           'close_approach_date_full': '1991-Aug-17 15:32',
#                           'epoch_date_close_approach': 682443120000,
#                           'miss_distance': {'astronomical': '0.3635086079',
#                                             'kilometers': '54380113.468505173',
#                                             'lunar': '141.4048484731',
#                                             'miles': '33790235.6352824674'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '22827.8785257793',
#                                                 'kilometers_per_second': '6.3410773683',
#                                                 'miles_per_hour': '14184.3559650877'}},
#                          {'close_approach_date': '1996-12-31',
#                           'close_approach_date_full': '1996-Dec-31 18:58',
#                           'epoch_date_close_approach': 852058680000,
#                           'miss_distance': {'astronomical': '0.2617182949',
#                                             'kilometers': '39152499.457071863',
#                                             'lunar': '101.8084167161',
#                                             'miles': '24328235.0473751894'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '57151.7185747439',
#                                                 'kilometers_per_second': '15.8754773819',
#                                                 'miles_per_hour': '35511.8553555124'}},
#                          {'close_approach_date': '1997-10-10',
#                           'close_approach_date_full': '1997-Oct-10 21:51',
#                           'epoch_date_close_approach': 876520260000,
#                           'miss_distance': {'astronomical': '0.4499913809',
#                                             'kilometers': '67317752.100998683',
#                                             'lunar': '175.0466471701',
#                                             'miles': '41829311.5046125054'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30320.8894053652',
#                                                 'kilometers_per_second': '8.4224692793',
#                                                 'miles_per_hour': '18840.2215307948'}},
#                          {'close_approach_date': '1998-07-11',
#                           'close_approach_date_full': '1998-Jul-11 12:30',
#                           'epoch_date_close_approach': 900160200000,
#                           'miss_distance': {'astronomical': '0.2461744738',
#                                             'kilometers': '36827176.928850806',
#                                             'lunar': '95.7618703082',
#                                             'miles': '22883346.6287048828'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '55503.3331124629',
#                                                 'kilometers_per_second': '15.4175925312',
#                                                 'miles_per_hour': '34487.6127331301'}},
#                          {'close_approach_date': '2003-02-15',
#                           'close_approach_date_full': '2003-Feb-15 17:49',
#                           'epoch_date_close_approach': 1045331340000,
#                           'miss_distance': {'astronomical': '0.1392391042',
#                                             'kilometers': '20829873.409028054',
#                                             'lunar': '54.1640115338',
#                                             'miles': '12943083.1576289852'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '8396.5779991187',
#                                                 'kilometers_per_second': '2.3323827775',
#                                                 'miles_per_hour': '5217.3070350635'}},
#                          {'close_approach_date': '2003-11-28',
#                           'close_approach_date_full': '2003-Nov-28 15:41',
#                           'epoch_date_close_approach': 1070034060000,
#                           'miss_distance': {'astronomical': '0.3309480583',
#                                             'kilometers': '49509124.602315821',
#                                             'lunar': '128.7387946787',
#                                             'miles': '30763543.5034114898'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '27266.6793848946',
#                                                 'kilometers_per_second': '7.5740776069',
#                                                 'miles_per_hour': '16942.4541989085'}},
#                          {'close_approach_date': '2004-05-03',
#                           'close_approach_date_full': '2004-May-03 17:57',
#                           'epoch_date_close_approach': 1083607020000,
#                           'miss_distance': {'astronomical': '0.1969885764',
#                                             'kilometers': '29469071.443772268',
#                                             'lunar': '76.6285562196',
#                                             'miles': '18311231.8920545784'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '26142.6378297677',
#                                                 'kilometers_per_second': '7.2618438416',
#                                                 'miles_per_hour': '16244.0184892798'}},
#                          {'close_approach_date': '2010-01-06',
#                           'close_approach_date_full': '2010-Jan-06 13:52',
#                           'epoch_date_close_approach': 1262785920000,
#                           'miss_distance': {'astronomical': '0.1258550631',
#                                             'kilometers': '18827649.368475597',
#                                             'lunar': '48.9576195459',
#                                             'miles': '11698958.8296413586'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '41890.9963477291',
#                                                 'kilometers_per_second': '11.6363878744',
#                                                 'miles_per_hour': '26029.4360361765'}},
#                          {'close_approach_date': '2010-09-27',
#                           'close_approach_date_full': '2010-Sep-27 21:53',
#                           'epoch_date_close_approach': 1285624380000,
#                           'miss_distance': {'astronomical': '0.4475362447',
#                                             'kilometers': '66950468.954918789',
#                                             'lunar': '174.0915991883',
#                                             'miles': '41601092.3403017282'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '29355.5755561512',
#                                                 'kilometers_per_second': '8.1543265434',
#                                                 'miles_per_hour': '18240.4130448763'}},
#                          {'close_approach_date': '2011-07-18',
#                           'close_approach_date_full': '2011-Jul-18 23:20',
#                           'epoch_date_close_approach': 1311031200000,
#                           'miss_distance': {'astronomical': '0.3838980282',
#                                             'kilometers': '57430327.315919934',
#                                             'lunar': '149.3363329698',
#                                             'miles': '35685550.6331417292'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '69611.3755954031',
#                                                 'kilometers_per_second': '19.3364932209',
#                                                 'miles_per_hour': '43253.8016859325'}},
#                          {'close_approach_date': '2016-11-14',
#                           'close_approach_date_full': '2016-Nov-14 21:24',
#                           'epoch_date_close_approach': 1479158640000,
#                           'miss_distance': {'astronomical': '0.3797958988',
#                                             'kilometers': '56816657.495215556',
#                                             'lunar': '147.7406046332',
#                                             'miles': '35304233.8884484328'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '28993.249749129',
#                                                 'kilometers_per_second': '8.0536804859',
#                                                 'miles_per_hour': '18015.2778788407'}},
#                          {'close_approach_date': '2017-06-07',
#                           'close_approach_date_full': '2017-Jun-07 19:17',
#                           'epoch_date_close_approach': 1496863020000,
#                           'miss_distance': {'astronomical': '0.1216010659',
#                                             'kilometers': '18191260.448369633',
#                                             'lunar': '47.3028146351',
#                                             'miles': '11303525.0911936154'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '24399.5266795501',
#                                                 'kilometers_per_second': '6.7776462999',
#                                                 'miles_per_hour': '15160.9170081905'}},
#                          {'close_approach_date': '2018-06-28',
#                           'close_approach_date_full': '2018-Jun-28 17:53',
#                           'epoch_date_close_approach': 1530208380000,
#                           'miss_distance': {'astronomical': '0.1299706247',
#                                             'kilometers': '19443328.617689389',
#                                             'lunar': '50.5585730083',
#                                             'miles': '12081524.1753120082'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '8131.6667622212',
#                                                 'kilometers_per_second': '2.2587963228',
#                                                 'miles_per_hour': '5052.7014945591'}},
#                          {'close_approach_date': '2023-01-09',
#                           'close_approach_date_full': '2023-Jan-09 13:59',
#                           'epoch_date_close_approach': 1673272740000,
#                           'miss_distance': {'astronomical': '0.0725378025',
#                                             'kilometers': '10851500.748480675',
#                                             'lunar': '28.2172051725',
#                                             'miles': '6742809.896856315'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '32387.3439078662',
#                                                 'kilometers_per_second': '8.9964844189',
#                                                 'miles_per_hour': '20124.2359965294'}},
#                          {'close_approach_date': '2023-09-19',
#                           'close_approach_date_full': '2023-Sep-19 00:06',
#                           'epoch_date_close_approach': 1695081960000,
#                           'miss_distance': {'astronomical': '0.4367403676',
#                                             'kilometers': '65335428.735977012',
#                                             'lunar': '169.8920029964',
#                                             'miles': '40597552.8829942856'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '28339.6715741898',
#                                                 'kilometers_per_second': '7.8721309928',
#                                                 'miles_per_hour': '17609.1698178625'}},
#                          {'close_approach_date': '2024-07-22',
#                           'close_approach_date_full': '2024-Jul-22 14:57',
#                           'epoch_date_close_approach': 1721660220000,
#                           'miss_distance': {'astronomical': '0.469890485',
#                                             'kilometers': '70294615.68926695',
#                                             'lunar': '182.787398665',
#                                             'miles': '43679048.76490591'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '78572.9402086795',
#                                                 'kilometers_per_second': '21.8258167246',
#                                                 'miles_per_hour': '48822.169431332'}},
#                          {'close_approach_date': '2029-11-08',
#                           'close_approach_date_full': '2029-Nov-08 09:25',
#                           'epoch_date_close_approach': 1888824300000,
#                           'miss_distance': {'astronomical': '0.4003634451',
#                                             'kilometers': '59893518.612821937',
#                                             'lunar': '155.7413801439',
#                                             'miles': '37216106.7322072506'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '29746.2095348593',
#                                                 'kilometers_per_second': '8.2628359819',
#                                                 'miles_per_hour': '18483.1378079241'}},
#                          {'close_approach_date': '2030-06-20',
#                           'close_approach_date_full': '2030-Jun-20 05:07',
#                           'epoch_date_close_approach': 1908162420000,
#                           'miss_distance': {'astronomical': '0.065151282',
#                                             'kilometers': '9746493.01496934',
#                                             'lunar': '25.343848698',
#                                             'miles': '6056189.930243292'},
#                           'orbiting_body': 'Earth',
# ...
#                                             'kilometers': '17203626.335992652',
#                                             'lunar': '44.7346653044',
#                                             'miles': '10689837.7108245176'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '42267.0608942983',
#                                                 'kilometers_per_second': '11.7408502484',
#                                                 'miles_per_hour': '26263.1079206822'}},
#                          {'close_approach_date': '2167-01-03',
#                           'close_approach_date_full': '2167-Jan-03 22:54',
#                           'epoch_date_close_approach': 6216994440000,
#                           'miss_distance': {'astronomical': '0.1705762473',
#                                             'kilometers': '25517843.268673251',
#                                             'lunar': '66.3541601997',
#                                             'miles': '15856052.5522268238'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '22184.4916206388',
#                                                 'kilometers_per_second': '6.1623587835',
#                                                 'miles_per_hour': '13784.5803628353'}},
#                          {'close_approach_date': '2167-09-04',
#                           'close_approach_date_full': '2167-Sep-04 01:04',
#                           'epoch_date_close_approach': 6237997440000,
#                           'miss_distance': {'astronomical': '0.4019438757',
#                                             'kilometers': '60129947.664264759',
#                                             'lunar': '156.3561676473',
#                                             'miles': '37363016.9324573142'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '25646.1160835097',
#                                                 'kilometers_per_second': '7.1239211343',
#                                                 'miles_per_hour': '15935.4991853341'}},
#                          {'close_approach_date': '2172-12-24',
#                           'close_approach_date_full': '2172-Dec-24 10:53',
#                           'epoch_date_close_approach': 6405475980000,
#                           'miss_distance': {'astronomical': '0.4677830958',
#                                             'kilometers': '69979354.753685946',
#                                             'lunar': '181.9676242662',
#                                             'miles': '43483154.7032642148'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '79561.3622776434',
#                                                 'kilometers_per_second': '22.1003784105',
#                                                 'miles_per_hour': '49436.3364663501'}},
#                          {'close_approach_date': '2173-11-02',
#                           'close_approach_date_full': '2173-Nov-02 13:07',
#                           'epoch_date_close_approach': 6432527220000,
#                           'miss_distance': {'astronomical': '0.4173356674',
#                                             'kilometers': '62432526.918068438',
#                                             'lunar': '162.3435746186',
#                                             'miles': '38793773.3357149244'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30265.1810138418',
#                                                 'kilometers_per_second': '8.4069947261',
#                                                 'miles_per_hour': '18805.6065027396'}},
#                          {'close_approach_date': '2174-06-28',
#                           'close_approach_date_full': '2174-Jun-28 18:01',
#                           'epoch_date_close_approach': 6453108060000,
#                           'miss_distance': {'astronomical': '0.0341017169',
#                                             'kilometers': '5101544.211583003',
#                                             'lunar': '13.2655678741',
#                                             'miles': '3169952.5804233214'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '32787.2021321744',
#                                                 'kilometers_per_second': '9.1075561478',
#                                                 'miles_per_hour': '20372.6923470725'}},
#                          {'close_approach_date': '2179-01-22',
#                           'close_approach_date_full': '2179-Jan-22 18:07',
#                           'epoch_date_close_approach': 6597310020000,
#                           'miss_distance': {'astronomical': '0.1265836075',
#                                             'kilometers': '18936638.058916025',
#                                             'lunar': '49.2410233175',
#                                             'miles': '11766681.261550145'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '8504.8273363237',
#                                                 'kilometers_per_second': '2.3624520379',
#                                                 'miles_per_hour': '5284.5689635062'}},
#                          {'close_approach_date': '2180-01-11',
#                           'close_approach_date_full': '2180-Jan-11 07:19',
#                           'epoch_date_close_approach': 6627856740000,
#                           'miss_distance': {'astronomical': '0.1105499149',
#                                             'kilometers': '16538031.797721263',
#                                             'lunar': '43.0039168961',
#                                             'miles': '10276256.4427609094'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '25028.3034763002',
#                                                 'kilometers_per_second': '6.9523065212',
#                                                 'miles_per_hour': '15551.61445726'}},
#                          {'close_approach_date': '2180-09-11',
#                           'close_approach_date_full': '2180-Sep-11 17:16',
#                           'epoch_date_close_approach': 6648974160000,
#                           'miss_distance': {'astronomical': '0.4212756781',
#                                             'kilometers': '63021944.126565647',
#                                             'lunar': '163.8762387809',
#                                             'miles': '39160020.2059820486'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '27151.3301699504',
#                                                 'kilometers_per_second': '7.5420361583',
#                                                 'miles_per_hour': '16870.780682545'}},
#                          {'close_approach_date': '2186-11-06',
#                           'close_approach_date_full': '2186-Nov-06 01:18',
#                           'epoch_date_close_approach': 6843057480000,
#                           'miss_distance': {'astronomical': '0.4105171081',
#                                             'kilometers': '61412484.970319747',
#                                             'lunar': '159.6911550509',
#                                             'miles': '38159948.6602246286'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30109.5490770077',
#                                                 'kilometers_per_second': '8.3637636325',
#                                                 'miles_per_hour': '18708.902869544'}},
#                          {'close_approach_date': '2187-06-26',
#                           'close_approach_date_full': '2187-Jun-26 02:37',
#                           'epoch_date_close_approach': 6863107020000,
#                           'miss_distance': {'astronomical': '0.0402610118',
#                                             'kilometers': '6022961.609324866',
#                                             'lunar': '15.6615335902',
#                                             'miles': '3742494.8022445108'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30166.0023059627',
#                                                 'kilometers_per_second': '8.379445085',
#                                                 'miles_per_hour': '18743.9807106133'}},
#                          {'close_approach_date': '2193-01-10',
#                           'close_approach_date_full': '2193-Jan-10 21:55',
#                           'epoch_date_close_approach': 7038136500000,
#                           'miss_distance': {'astronomical': '0.0818031373',
#                                             'kilometers': '12237575.099397551',
#                                             'lunar': '31.8214204097',
#                                             'miles': '7604076.5610501638'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '28590.9002805339',
#                                                 'kilometers_per_second': '7.9419167446',
#                                                 'miles_per_hour': '17765.2735659795'}},
#                          {'close_approach_date': '2193-09-16',
#                           'close_approach_date_full': '2193-Sep-16 23:41',
#                           'epoch_date_close_approach': 7059656460000,
#                           'miss_distance': {'astronomical': '0.4305039114',
#                                             'kilometers': '64402468.172108718',
#                                             'lunar': '167.4660215346',
#                                             'miles': '40017838.0703395884'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '27939.5929345009',
#                                                 'kilometers_per_second': '7.7609980374',
#                                                 'miles_per_hour': '17360.5765097736'}},
#                          {'close_approach_date': '2194-07-26',
#                           'close_approach_date_full': '2194-Jul-26 01:01',
#                           'epoch_date_close_approach': 7086618060000,
#                           'miss_distance': {'astronomical': '0.4918243047',
#                                             'kilometers': '73575868.397350989',
#                                             'lunar': '191.3196545283',
#                                             'miles': '45717924.6537780882'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '81015.8441679468',
#                                                 'kilometers_per_second': '22.5044011578',
#                                                 'miles_per_hour': '50340.0949498001'}},
#                          {'close_approach_date': '2199-11-12',
#                           'close_approach_date_full': '2199-Nov-12 07:46',
#                           'epoch_date_close_approach': 7253826360000,
#                           'miss_distance': {'astronomical': '0.3930013068',
#                                             'kilometers': '58792158.404496516',
#                                             'lunar': '152.8775083452',
#                                             'miles': '36531753.2326472808'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '29592.9981570477',
#                                                 'kilometers_per_second': '8.2202772658',
#                                                 'miles_per_hour': '18387.9382159722'}},
#                          {'close_approach_date': '2200-06-17',
#                           'close_approach_date_full': '2200-Jun-17 14:23',
#                           'epoch_date_close_approach': 7272598980000,
#                           'miss_distance': {'astronomical': '0.0918595631',
#                                             'kilometers': '13741994.978890597',
#                                             'lunar': '35.7333700459',
#                                             'miles': '8538879.7267683586'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '25707.9887156854',
#                                                 'kilometers_per_second': '7.1411079766',
#                                                 'miles_per_hour': '15973.9444328102'}}],
#  'designation': '226554',
#  'estimated_diameter': {'feet': {'estimated_diameter_max': 2312.1980468998,
#                                  'estimated_diameter_min': 1034.046402062},
#                         'kilometers': {'estimated_diameter_max': 0.7047579421,
#                                        'estimated_diameter_min': 0.3151773333},
#                         'meters': {'estimated_diameter_max': 704.7579421428,
#                                    'estimated_diameter_min': 315.1773332628},
#                         'miles': {'estimated_diameter_max': 0.4379161473,
#                                   'estimated_diameter_min': 0.1958420547}},
#  'id': '2226554',
#  'is_potentially_hazardous_asteroid': True,
#  'is_sentry_object': False,
#  'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2226554?api_key=cMYIfUR8gTcV62HNrLgfqP4Rk5lBJPtX3C7Sr0dH'},
#  'name': '226554 (2003 WR21)',
#  'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2226554',
#  'neo_reference_id': '2226554',
#  'orbital_data': {'aphelion_distance': '1.410761843467234',
#                   'ascending_node_longitude': '85.77039810161033',
#                   'data_arc_in_days': 12071,
#                   'eccentricity': '.261534463213791',
#                   'epoch_osculation': '2460200.5',
#                   'equinox': 'J2000',
#                   'first_observation_date': '1990-10-24',
#                   'inclination': '9.264967952574843',
#                   'jupiter_tisserand_invariant': '5.536',
#                   'last_observation_date': '2023-11-11',
#                   'mean_anomaly': '149.7388143094432',
#                   'mean_motion': '.8334358843578928',
#                   'minimum_orbit_intersection': '.0303468',
#                   'observations_used': 514,
#                   'orbit_class': {'orbit_class_description': 'Near-Earth '
#                                                              'asteroid orbits '
#                                                              'which cross the '
#                                                              'Earth’s orbit '
#                                                              'similar to that '
#                                                              'of 1862 Apollo',
#                                   'orbit_class_range': 'a (semi-major axis) > '
#                                                        '1.0 AU; q (perihelion) '
#                                                        '< 1.017 AU',
#                                   'orbit_class_type': 'APO'},
#                   'orbit_determination_date': '2024-01-07 05:31:33',
#                   'orbit_id': '120',
#                   'orbit_uncertainty': '0',
#                   'orbital_period': '431.9468440902999',
#                   'perihelion_argument': '108.0868093041561',
#                   'perihelion_distance': '.825818899437375',
#                   'perihelion_time': '2460020.835532558924',
#                   'semi_major_axis': '1.118290371452304'}}

# %% [markdown]
# Notice that the `miss_distance` field contains the distance (in various units) by which the NEO missed an "orbiting body".
#
# ## Exercise 2
#
# In the code cell below, write a python function that takes a list of "close approach data" as a parameter,
# and returns a 2-tuple with the (date, miss km) of the closest approach to Earth in the list (where "miss km" is the miss distance in km).
#
# Hints:
# * notice the input is a list of dictionaries.  Each dictionary has a 'close_approach_date", "orbiting_body", and 'miss_distance' field.
# * we are only interested in the closest approach to "Earth"
# * use a loop if that is easier to understand - we will look at more compact algorithms to solve this problem in class.
#
# Add at least one unit test to check your work - note the test data only needs dictionaries with the fields your function actually uses.

# %%
# Ex. 2 your code here
def get_miss_data(d):
  cap_data = d['close_approach_data']
  missd = [dist['miss_distance'] for dist in cap_data]
  kilometers = [float(km['kilometers']) for km in missd]
  dates = [day['close_approach_date'] for day in cap_data]
  min_index = kilometers.index(min(kilometers))
  return kilometers[min_index], dates[min_index]
print(get_miss_data(data))
# Out:
# (4303819.733240247, '1972-06-25')
# [{'absolute_magnitude_h': 19.63,
#   'close_approach_data': [{'close_approach_date': '2023-01-09',
#                            'close_approach_date_full': '2023-Jan-09 13:59',
#                            'epoch_date_close_approach': 1673272740000,
#                            'miss_distance': {'astronomical': '0.0725378025',
#                                              'kilometers': '10851500.748480675',
#                                              'lunar': '28.2172051725',
#                                              'miles': '6742809.896856315'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '32387.3439078662',
#                                                  'kilometers_per_second': '8.9964844189',
#                                                  'miles_per_hour': '20124.2359965294'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 2312.1980468998,
#                                   'estimated_diameter_min': 1034.046402062},
#                          'kilometers': {'estimated_diameter_max': 0.7047579421,
#                                         'estimated_diameter_min': 0.3151773333},
#                          'meters': {'estimated_diameter_max': 704.7579421428,
#                                     'estimated_diameter_min': 315.1773332628},
#                          'miles': {'estimated_diameter_max': 0.4379161473,
#                                    'estimated_diameter_min': 0.1958420547}},
#   'id': '2226554',
#   'is_potentially_hazardous_asteroid': True,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2226554?api_key=cMYIfUR8gTcV62HNrLgfqP4Rk5lBJPtX3C7Sr0dH'},
#   'name': '226554 (2003 WR21)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2226554',
#   'neo_reference_id': '2226554'},
#  {'absolute_magnitude_h': 20.95,
#   'close_approach_data': [{'close_approach_date': '2023-01-09',
#                            'close_approach_date_full': '2023-Jan-09 03:25',
#                            'epoch_date_close_approach': 1673234700000,
#                            'miss_distance': {'astronomical': '0.1211166399',
#                                              'kilometers': '18118791.350597013',
#                                              'lunar': '47.1143729211',
#                                              'miles': '11258494.8819162594'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '22658.3665761987',
#                                                  'kilometers_per_second': '6.2939907156',
#                                                  'miles_per_hour': '14079.0278317497'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 1258.997970434,
#                                   'estimated_diameter_min': 563.0410090849},
#                          'kilometers': {'estimated_diameter_max': 0.3837425691,
#                                         'estimated_diameter_min': 0.1716148941},
#                          'meters': {'estimated_diameter_max': 383.7425691085,
#                                     'estimated_diameter_min': 171.6148940774},
#                          'miles': {'estimated_diameter_max': 0.2384465039,
#                                    'estimated_diameter_min': 0.1066365183}},
#   'id': '2508908',
#   'is_potentially_hazardous_asteroid': True,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2508908?api_key=cMYIfUR8gTcV62HNrLgfqP4Rk5lBJPtX3C7Sr0dH'},
#   'name': '508908 (2003 YX1)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2508908',
#   'neo_reference_id': '2508908'},
#  {'absolute_magnitude_h': 21.42,
#   'close_approach_data': [{'close_approach_date': '2023-01-09',
#                            'close_approach_date_full': '2023-Jan-09 07:10',
#                            'epoch_date_close_approach': 1673248200000,
#                            'miss_distance': {'astronomical': '0.4928732055',
#                                              'kilometers': '73732781.722872285',
#                                              'lunar': '191.7276769395',
#                                              'miles': '45815426.073056133'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '121198.8588141982',
#                                                  'kilometers_per_second': '33.6663496706',
#                                                  'miles_per_hour': '75308.2575781889'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 1013.9698229009,
#                                   'estimated_diameter_min': 453.461090228},
#                          'kilometers': {'estimated_diameter_max': 0.3090579921,
#                                         'estimated_diameter_min': 0.1382149359},
#                          'meters': {'estimated_diameter_max': 309.0579921303,
#                                     'estimated_diameter_min': 138.2149358786},
#                          'miles': {'estimated_diameter_max': 0.1920396736,
#                                    'estimated_diameter_min': 0.0858827529}},
#   'id': '3014110',
#   'is_potentially_hazardous_asteroid': True,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3014110?api_key=cMYIfUR8gTcV62HNrLgfqP4Rk5lBJPtX3C7Sr0dH'},
#   'name': '(1998 SU4)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3014110',
#   'neo_reference_id': '3014110'}]

# %% [markdown]
# ## Challenge - Take your skills to the next level...
# ## Exercise 3
#
# In the code cell below, write a complete program that:
#  1. fetches the list of NEO's for this week.
#  2. for each NEO, fetch it's complete orbital data and determine its closest approach to Earth
#  3. identify which NEO from this week's data makes the closet approach to earth
#  4. print a nice message with information about the NEO, which it will approach the Earth, and how close it will come.
#
# Hints:
# * you'll need the start and end date - end date is today, see if you can use a [`timedelta`](https://docs.python.org/3/library/datetime.html#timedelta-objects) object to ge the start date (you can do basic "date math" with `timedelta` and `date` objects!)
# * you may need to modify the function we wrote in Ex. 2 to return a triple with the NEO's id included;
# * lots of opportunity here for more practice with list comprehensions

# %%
# Ex. 3 (challenge) your code here
#API_KEY = 'cMYIfUR8gTcV62HNrLgfqP4Rk5lBJPtX3C7Sr0dH'  # substitute your API key here

#today = str(datetime.date.today())  #  Future enhancement:  str(datetime.date.today())   # Today's date as a string!
# Use an f-string here to "format" the date and API key varaibles.
#url = f'https://api.nasa.gov/neo/rest/v1/feed?start_date={today}&end_date={today}&api_key={API_KEY}'

#response = requests.request("GET", url, headers={}, data={})

#data = json.loads(response.text)  # recall json.loads for lab 1

# TIP: print(data) to see the whole data structure returned, here we grab just the list of NEO's:
#n_results = data['element_count']
#neos = data['near_earth_objects'][today]
API_KEY = 'cMYIfUR8gTcV62HNrLgfqP4Rk5lBJPtX3C7Sr0dH'

today = datetime.date.today()
delta = datetime.timedelta(weeks=-1)
start = str(today + delta)
end = str(today)

url = f'https://api.nasa.gov/neo/rest/v1/feed?start_date={start}&end_date={end}&api_key={API_KEY}'

response = requests.request("GET", url, headers={}, data={})

data = json.loads(response.text)
neos = data['near_earth_objects']

pprint(neos.values())
# Out:
# dict_values([[{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3147312?api_key=cMYIfUR8gTcV62HNrLgfqP4Rk5lBJPtX3C7Sr0dH'}, 'id': '3147312', 'neo_reference_id': '3147312', 'name': '(2003 BN1)', 'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3147312', 'absolute_magnitude_h': 20.24, 'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.2379879547, 'estimated_diameter_max': 0.5321572445}, 'meters': {'estimated_diameter_min': 237.9879546831, 'estimated_diameter_max': 532.1572444975}, 'miles': {'estimated_diameter_min': 0.1478788134, 'estimated_diameter_max': 0.3306670792}, 'feet': {'estimated_diameter_min': 780.8004012424, 'estimated_diameter_max': 1745.9227740372}}, 'is_potentially_hazardous_asteroid': False, 'close_approach_data': [{'close_approach_date': '2024-01-13', 'close_approach_date_full': '2024-Jan-13 21:51', 'epoch_date_close_approach': 1705182660000, 'relative_velocity': {'kilometers_per_second': '32.0920709651', 'kilometers_per_hour': '115531.455474504', 'miles_per_hour': '71786.7535419217'}, 'miss_distance': {'astronomical': '0.1592234555', 'lunar': '61.9379241895', 'kilometers': '23819489.796839785', 'miles': '14800744.640107633'}, 'orbiting_body': 'Earth'}], 'is_sentry_object': False}, {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3728898?api_key=cMYIfUR8gTcV62HNrLgfqP4Rk5lBJPtX3C7Sr0dH'}, 'id': '3728898', 'neo_reference_id': '3728898', 'name': '(2015 TF)', 'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3728898', 'absolute_magnitude_h': 22.14, 'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0992098919, 'estimated_diameter_max': 0.2218400624}, 'meters': {'estimated_diameter_min': 99.2098919421, 'estimated_diameter_max': 221.8400624229}, 'miles': {'estimated_diameter_min': 0.0616461498, 'estimated_diameter_max': 0.1378449814}, 'feet': {'estimated_diameter_min': 325.4917818793, 'estimated_diameter_max': 727.8217503997}}, 'is_potentially_hazardous_asteroid': False, 'close_approach_data': [{'close_approach_date': '2024-01-13', 'close_approach_date_full': '2024-Jan-13 12:35', 'epoch_date_close_approach': 1705149300000, 'relative_velocity': {'kilometers_per_second': '16.7006802273', 'kilometers_per_hour': '60122.448818455', 'miles_per_hour': '37357.7516005561'}, 'miss_distance': {'astronomical': '0.4280737173', 'lunar': '166.5206760297', 'kilometers': '64038916.311062151', 'miles': '39791937.4190376438'}, 'orbiting_body': 'Earth'}], 'is_sentry_object': False}, {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3781591?api_key=cMYIfUR8gTcV62HNrLgfqP4Rk5lBJPtX3C7Sr0dH'}, 'id': '3781591', 'neo_reference_id': '3781591', 'name': '(2017 SM2)', 'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3781591', 'absolute_magnitude_h': 27.3, 'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0092162655, 'estimated_diameter_max': 0.0206081961}, 'meters': {'estimated_diameter_min': 9.216265485, 'estimated_diameter_max': 20.6081961232}, 'miles': {'estimated_diameter_min': 0.0057267201, 'estimated_diameter_max': 0.0128053354}, 'feet': {'estimated_diameter_min': 30.2370924539, 'estimated_diameter_max': 67.6121941689}}, 'is_potentially_hazardous_asteroid': False, 'close_approach_data': [{'close_approach_date': '2024-01-13', 'close_approach_date_full': '2024-Jan-13 20:52', 'epoch_date_close_approach': 1705179120000, 'relative_velocity': {'kilometers_per_second': '7.65680023', 'kilometers_per_hour': '27564.4808280082', 'miles_per_hour': '17127.4964344921'}, 'miss_distance': {'astronomical': '0.090718593', 'lunar': '35.289532677', 'kilometers': '13571308.28219691', 'miles': '8432819.931500958'}, 'orbiting_body': 'Earth'}], 'is_sentry_object': False}, {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3790060?api_key=cMYIfUR8gTcV62HNrLgfqP4Rk5lBJPtX3C7Sr0dH'}, 'id': '3790060', 'neo_reference_id': '3790060', 'name': '(2017 WP28)', 'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=379006 ...
